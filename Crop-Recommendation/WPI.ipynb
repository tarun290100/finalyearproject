# %%
import pandas as pd
import numpy as np
df=pd.read_csv('rice.csv',index_col='Date',parse_dates=True)
df.tail()
df=df.dropna()
rice = df
# df.index.freq='MS'
# rice=df.drop(['Cotton','Maize','Moong','Urad','Apple','Coconut','Coffee','Pigeon Peas'],axis=1)

# %% [markdown]
# # RICE

# %%
rice
# Out:
#              Rice
# Date
# 2011-01-04   97.5
# 2011-01-05   98.9
# 2011-01-06   99.4
# 2011-01-07  100.1
# 2011-01-08  101.3
# ...           ...
# 2020-01-11  163.1
# 2020-01-12  162.2
# 2021-01-01  162.1
# 2021-01-02  161.7
# 2021-01-03  161.5
#
# [120 rows x 1 columns]

# %%
rice['last_year']=rice['Rice'].shift(+12)
rice['11']=rice['Rice'].shift(+11)
rice['10']=rice['Rice'].shift(+10)
rice['9']=rice['Rice'].shift(+9)
rice['8']=rice['Rice'].shift(+8)
rice['7']=rice['Rice'].shift(+7)
rice['6']=rice['Rice'].shift(+6)
rice['5']=rice['Rice'].shift(+5)
rice['4']=rice['Rice'].shift(+4)
rice['3']=rice['Rice'].shift(+3)
rice['2']=rice['Rice'].shift(+2)
rice['1']=rice['Rice'].shift(+1)

# %%
df['Rice'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
rice['last_year'].dropna()
# Out:
# Date
# 2012-01-04     97.5
# 2012-01-05     98.9
# 2012-01-06     99.4
# 2012-01-07    100.1
# 2012-01-08    101.3
#               ...
# 2020-01-11    162.1
# 2020-01-12    162.0
# 2021-01-01    162.3
# 2021-01-02    162.3
# 2021-01-03    159.3
# Name: last_year, Length: 108, dtype: float64

# %%
rice=rice.dropna()

# %%
x=rice.drop(['Rice'],axis=1)
x
# Out:
#             last_year     11     10      9      8      7      6      5      4  \
# Date
# 2012-01-04       97.5   98.9   99.4  100.1  101.3  101.5  101.5  100.8   99.2
# 2012-01-05       98.9   99.4  100.1  101.3  101.5  101.5  100.8   99.2   99.5
# 2012-01-06       99.4  100.1  101.3  101.5  101.5  100.8   99.2   99.5   99.5
# 2012-01-07      100.1  101.3  101.5  101.5  100.8   99.2   99.5   99.5  100.9
# 2012-01-08      101.3  101.5  101.5  100.8   99.2   99.5   99.5  100.9  104.2
# ...               ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2020-01-11      162.1  162.0  162.3  162.3  159.3  162.7  163.1  165.6  165.8
# 2020-01-12      162.0  162.3  162.3  159.3  162.7  163.1  165.6  165.8  165.4
# 2021-01-01      162.3  162.3  159.3  162.7  163.1  165.6  165.8  165.4  165.0
# 2021-01-02      162.3  159.3  162.7  163.1  165.6  165.8  165.4  165.0  163.7
# 2021-01-03      159.3  162.7  163.1  165.6  165.8  165.4  165.0  163.7  163.1
#
# ...

# %%
x1,x2,x3,x4,x5,x6,x7=rice['1'],rice['2'],rice['3'],rice['4'],rice['5'],rice['6'],rice['7']
x1,x2,x3,x4,x5,x6,x7=np.array(x1),np.array(x2),np.array(x3),np.array(x4),np.array(x5),np.array(x6),np.array(x7)
x1,x2,x3,x4,x5,x6,x7=x1.reshape(-1,1),x2.reshape(-1,1),x3.reshape(-1,1),x4.reshape(-1,1),x5.reshape(-1,1),x6.reshape(-1,1),x7.reshape(-1,1)
x=np.concatenate((x1,x2,x3,x4,x5,x6,x7),axis=1)
x
# Out:
# array([[100.9,  99.5,  99.5,  99.2, 100.8, 101.5, 101.5],
#        [104.2, 100.9,  99.5,  99.5,  99.2, 100.8, 101.5],
#        [104.2, 104.2, 100.9,  99.5,  99.5,  99.2, 100.8],
#        [107. , 104.2, 104.2, 100.9,  99.5,  99.5,  99.2],
#        [111. , 107. , 104.2, 104.2, 100.9,  99.5,  99.5],
#        [114. , 111. , 107. , 104.2, 104.2, 100.9,  99.5],
#        [116.1, 114. , 111. , 107. , 104.2, 104.2, 100.9],
#        [116.6, 116.1, 114. , 111. , 107. , 104.2, 104.2],
#        [116.3, 116.6, 116.1, 114. , 111. , 107. , 104.2],
#        [115.9, 116.3, 116.6, 116.1, 114. , 111. , 107. ],
#        [116.7, 115.9, 116.3, 116.6, 116.1, 114. , 111. ],
#        [117.9, 116.7, 115.9, 116.3, 116.6, 116.1, 114. ],
#        [118.7, 117.9, 116.7, 115.9, 116.3, 116.6, 116.1],
#        [120.4, 118.7, 117.9, 116.7, 115.9, 116.3, 116.6],
#        [121.9, 120.4, 118.7, 117.9, 116.7, 115.9, 116.3],
#        [124.9, 121.9, 120.4, 118.7, 117.9, 116.7, 115.9],
# ...

# %%
y=rice['Rice']

# %%
from sklearn.model_selection import train_test_split
Xtrain, Xtest, Ytrain, Ytest = x[:-6],x[-6:],y[:-6],y[-6:]

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(Xtrain, Ytrain)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(Xtest)
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(Ytest, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(Ytest, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(Ytest, y_pred)))
print('R2: ', metrics.r2_score(Ytest, y_pred))
# Out:
# Mean Absolute Error: 0.42676244551750625
# Mean Squared Error: 0.23777540781338216
# Root Mean Squared Error: 0.4876221978267418
# R2:  0.6046228784627347

# %%
X=test.reset_index(drop=true)
X=X.drop(['Date'],axis=1)
X.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 X=test.reset_index(drop=true)
#       2 X=X.drop(['Date'],axis=1)
#       3 X.tail()
#
# NameError: name 'test' is not defined

# %%
X.loc[len(X.index)] =[162.3,159.3,162.7,163.1,165.6,165.8,165.4,165.0,163.7,163.1,162.2,162.1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 X.loc[len(X.index)] =[162.3,159.3,162.7,163.1,165.6,165.8,165.4,165.0,163.7,163.1,162.2,162.1]
#
# NameError: name 'X' is not defined

# %%
model.predict(X)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 model.predict(X)
#
# NameError: name 'X' is not defined

# %%
X.loc[len(X.index)] =[159.3,162.7,163.1,165.6,165.8,165.4,165.0,163.7,163.1,162.2,162.1,161.7]
model.predict(X)
# Out:
# array([165.38507121, 164.5073708 , 163.27699752, 161.95762342,
#        162.57965697, 160.94368639, 160.94368639, 162.84700841])

# %%
X.loc[len(X.index)] =[162.7,163.1,165.6,165.8,165.4,165.0,163.7,163.1,162.2,162.1,161.7,162.8]
model.predict(X)
# Out:
# array([165.38507121, 164.5073708 , 163.27699752, 161.95762342,
#        162.57965697, 160.94368639, 160.94368639, 162.84700841,
#        163.27537057])

# %%
X.loc[len(X.index)] =[163.1,165.6,165.8,165.4,165.0,163.7,163.1,162.2,162.1,161.7,162.8,163.3]
model.predict(X)
# Out:
# array([165.38507121, 164.5073708 , 163.27699752, 161.95762342,
#        162.57965697, 160.94368639, 160.94368639, 162.84700841,
#        163.27537057, 164.14197766])

# %%
X.loc[len(X.index)] =[165.6,165.8,165.4,165.0,163.7,163.1,162.2,162.1,161.7,162.8,163.3,164.14]
model.predict(X)
# Out:
# array([165.38507121, 164.5073708 , 163.27699752, 161.95762342,
#        162.57965697, 160.94368639, 160.94368639, 162.84700841,
#        163.27537057, 164.14197766, 164.7197906 ])

# %%
X.loc[len(X.index)] =[165.8,165.4,165.0,163.7,163.1,162.2,162.1,161.7,162.8,163.3,164.14,164.7]
model.predict(X)
# Out:
# array([165.38507121, 164.5073708 , 163.27699752, 161.95762342,
#        162.57965697, 160.94368639, 160.94368639, 162.84700841,
#        163.27537057, 164.14197766, 164.7197906 , 164.72671682])

# %%
X.loc[len(X.index)] =[165.4,165.0,163.7,163.1,162.2,162.1,161.7,162.8,163.3,164.14,164.7,164.7]
model.predict(X)
# Out:
# array([165.38507121, 164.5073708 , 163.27699752, 161.95762342,
#        162.57965697, 160.94368639, 160.94368639, 162.84700841,
#        163.27537057, 164.14197766, 164.7197906 , 164.72671682,
#        164.66877249])

# %%
X.loc[len(X.index)] =[165.0,163.7,163.1,162.2,162.1,161.7,162.8,163.3,164.14,164.7,164.7,164.6]
model.predict(X)
# Out:
# array([165.38507121, 164.5073708 , 163.27699752, 161.95762342,
#        162.57965697, 160.94368639, 160.94368639, 162.84700841,
#        163.27537057, 164.14197766, 164.7197906 , 164.72671682,
#        164.66877249, 164.08066612])

# %%
X.loc[len(X.index)] =[163.7,163.1,162.2,162.1,161.7,162.8,163.3,164.14,164.7,164.7,164.6,165.1]
model.predict(X)
# Out:
# array([165.38507121, 164.5073708 , 163.27699752, 161.95762342,
#        162.57965697, 160.94368639, 160.94368639, 162.84700841,
#        163.27537057, 164.14197766, 164.7197906 , 164.72671682,
#        164.66877249, 164.08066612, 165.02547874])

# %%
X.loc[len(X.index)] =[163.1,162.2,162.1,161.7,162.8,163.3,164.14,164.7,164.7,164.6,165.1,165.0]
model.predict(X)
# Out:
# array([165.38507121, 164.5073708 , 163.27699752, 161.95762342,
#        162.57965697, 160.94368639, 160.94368639, 162.84700841,
#        163.27537057, 164.14197766, 164.7197906 , 164.72671682,
#        164.66877249, 164.08066612, 165.02547874, 164.41988113])

# %%
X.loc[len(X.index)] =[162.2,162.1,161.7,162.8,163.3,164.14,164.7,164.7,164.6,165.1,165.0,164.4]
model.predict(X)#dec
# Out:
# array([165.38507121, 164.5073708 , 163.27699752, 161.95762342,
#        162.57965697, 160.94368639, 160.94368639, 162.84700841,
#        163.27537057, 164.14197766, 164.7197906 , 164.72671682,
#        164.66877249, 164.08066612, 165.02547874, 164.41988113,
#        164.29862693])

# %%
X.loc[len(X.index)] =[162.1,161.7,162.8,163.3,164.14,164.7,164.7,164.6,165.1,165.0,164.4,164.3]
model.predict(X)
# Out:
# array([165.38507121, 164.5073708 , 163.27699752, 161.95762342,
#        162.57965697, 160.94368639, 160.94368639, 162.84700841,
#        163.27537057, 164.14197766, 164.7197906 , 164.72671682,
#        164.66877249, 164.08066612, 165.02547874, 164.41988113,
#        164.29862693, 164.01169762])

# %%
model.predict(X.iloc[4:])
# Out:
# c:\Users\acer\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:413: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[104], line 1
# ----> 1 model.predict(X.iloc[4:])
#
# File c:\Users\acer\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_base.py:354, in LinearModel.predict(self, X)
#     340 def predict(self, X):
#     341     """
#     342     Predict using the linear model.
#     343
#    (...)
#     352         Returns predicted values.
#     353     """
# --> 354     return self._decision_function(X)
#
# File c:\Users\acer\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_base.py:337, in LinearModel._decision_function(self, X)
#     334 def _decision_function(self, X):
# ...

# %%
X
# Out:
#    last_year     11     10      9      8      7      6      5      4      3  \
# 0      161.9  162.7  162.1  162.0  162.3  162.3  159.3  162.7  163.1  165.6
# 1      162.7  162.1  162.0  162.3  162.3  159.3  162.7  163.1  165.6  165.8
# 2      162.1  162.0  162.3  162.3  159.3  162.7  163.1  165.6  165.8  165.4
# 3      162.0  162.3  162.3  159.3  162.7  163.1  165.6  165.8  165.4  165.0
# 4      162.3  162.3  159.3  162.7  163.1  165.6  165.8  165.4  165.0  163.7
# 5      162.3  159.3  162.7  163.1  165.6  165.8  165.4  165.0  163.7  163.1
# 6      163.1  162.2  162.1  160.9  161.8  162.2  162.9  163.5  163.6  163.7
#
#        2      1
# 0  165.8  165.4
# 1  165.4  165.0
# 2  165.0  163.7
# 3  163.7  163.1
# 4  163.1  162.2
# 5  162.2  162.1
# 6  163.3  163.1

# %%
y_pred
# Out:
# array([165.38507121, 164.5073708 , 163.27699752, 161.95762342,
#        162.57965697, 160.94368639])

# %%
Ytest=Ytest.reset_index()

# %%
import matplotlib.pyplot as plt
plt.title('6-month Prediction')
plt.xlabel('Number of Months')
plt.ylabel('WPI')
plt.rcParams["figure.figsize"] = (11,6)
plt.plot(y_pred,label='Linear_Regression_Predictions')
plt.plot(Ytest['Rice'],label='Actual Sales')
plt.legend(loc="upper left")
plt.show()

# %%
from sklearn.model_selection import train_test_split
Xtrain, Xtest, Ytrain, Ytest = x[:-6],x[-6:],y[:-6],y[-6:]
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(Xtrain, Ytrain)
y_pred=model.predict(Xtest)
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(Ytest, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(Ytest, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(Ytest, y_pred)))
print('R2: ', metrics.r2_score(Ytest, y_pred))
# Out:
# Mean Absolute Error: 0.4746311150240814
# Mean Squared Error: 0.2820471768945077
# Root Mean Squared Error: 0.5310811396524148
# R2:  0.778303529078554

# %%
import matplotlib.pyplot as plt
plt.title('2 year Prediction')
plt.xlabel('Number of Months')
plt.ylabel('WPI')
plt.rcParams["figure.figsize"] = (11,6)
plt.plot(y_pred,label='Linear_Regression_Predictions')
plt.plot(Ytest['Rice'],label='Actual Sales')
plt.legend(loc="upper left")
plt.show()

# %%
from sklearn.model_selection import train_test_split
Xtrain, Xtest, Ytrain, Ytest = x[:-36],x[-36:],y[:-36],y[-36:]
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(Xtrain, Ytrain)
y_pred=model.predict(Xtest)
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(Ytest, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(Ytest, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(Ytest, y_pred)))
print('R2: ', metrics.r2_score(Ytest, y_pred))
# Out:
# Mean Absolute Error: 1.307456560557124
# Mean Squared Error: 3.2672468141489084
# Root Mean Squared Error: 1.8075527140719598
# R2:  0.7836508028301383

# %%
import matplotlib.pyplot as plt
plt.title('1 year Prediction')
plt.xlabel('Number of Months')
plt.ylabel('WPI')
plt.rcParams["figure.figsize"] = (11,6)
plt.plot(y_pred,label='Linear_Regression_Predictions')
plt.plot(Ytest['Rice'],label='Actual Sales')
plt.legend(loc="upper left")
plt.show()

# %%
y1=y.reset_index()
y1
# Out:
#           Date   Rice
# 0   2012-04-01  104.2
# 1   2012-05-01  104.2
# 2   2012-06-01  107.0
# 3   2012-07-01  111.0
# 4   2012-08-01  114.0
# ..         ...    ...
# 102 2020-10-01  163.7
# 103 2020-11-01  163.1
# 104 2020-12-01  162.2
# 105 2021-01-01  162.1
# 106 2021-02-01  161.7
#
# [107 rows x 2 columns]

# %%
y_pred=model.predict(x)
import matplotlib.pyplot as plt
plt.title('Prediction over entire dataset')
plt.xlabel('Number of Months')
plt.ylabel('WPI')
plt.rcParams["figure.figsize"] = (11,6)
plt.plot(y_pred,label='Linear_Regression_Predictions')
plt.plot(y1['Rice'],label='Actual Sales')
plt.legend(loc="upper left")
plt.show()

# %%
from sklearn.tree import DecisionTreeRegressor 
dtmodel = DecisionTreeRegressor()
dtmodel.fit(Xtrain, Ytrain)
# Out:
# DecisionTreeRegressor()

# %%
y_pred=dtmodel.predict(Xtest)
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(Ytest, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(Ytest, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(Ytest, y_pred)))
print('R2: ', metrics.r2_score(Ytest, y_pred))
# Out:
# Mean Absolute Error: 0.0007368998235212457
# Mean Squared Error: 8.315134716259493e-07
# Root Mean Squared Error: 0.0009118736050714207
# R2:  -0.6707770438102332

# %%
from sklearn.ensemble import RandomForestRegressor 
dtmodel = RandomForestRegressor()
dtmodel.fit(Xtrain, Ytrain)
# Out:
# RandomForestRegressor()

# %%
y_pred=dtmodel.predict(Xtest)
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(Ytest, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(Ytest, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(Ytest, y_pred)))
print('R2: ', metrics.r2_score(Ytest, y_pred))
# Out:
# Mean Absolute Error: 0.0006518391648819998
# Mean Squared Error: 6.196209380675537e-07
# Root Mean Squared Error: 0.0007871600460310176
# R2:  -0.24501703762309046

# %% [markdown]
# # MAIZE

# %%
df['Maize'].plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-8f65c8a72664> in <module>
# ----> 1 df['Maize'].plot()
#
# NameError: name 'df' is not defined

# %%
df=pd.read_csv('rice.csv',index_col='Date',parse_dates=True)
df.tail()
df=df.dropna()
df.index.freq='MS'
rice=df.drop(['Cotton','Rice','Moong','Urad','Apple','Coconut','Coffee','Pigeon Peas'],axis=1)
rice['last_year']=rice['Maize'].shift(+12)
rice['11']=rice['Maize'].shift(+11)
rice['10']=rice['Maize'].shift(+10)
rice['9']=rice['Maize'].shift(+9)
rice['8']=rice['Maize'].shift(+8)
rice['7']=rice['Maize'].shift(+7)
rice['6']=rice['Maize'].shift(+6)
rice['5']=rice['Maize'].shift(+5)
rice['4']=rice['Maize'].shift(+4)
rice['3']=rice['Maize'].shift(+3)
rice['2']=rice['Maize'].shift(+2)
rice['1']=rice['Maize'].shift(+1)

# %%
rice
# Out:
#             Maize  last_year     11     10      9      8      7      6      5  \
# Date
# 2011-04-01   98.2        NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2011-05-01  100.8        NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2011-06-01   99.5        NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2011-07-01   99.1        NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2011-08-01   99.6        NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ...           ...        ...    ...    ...    ...    ...    ...    ...    ...
# 2020-10-01  137.9      183.6  172.4  175.6  178.8  167.0  158.5  155.4  152.0
# 2020-11-01  139.8      172.4  175.6  178.8  167.0  158.5  155.4  152.0  148.4
# 2020-12-01  140.5      175.6  178.8  167.0  158.5  155.4  152.0  148.4  147.6
# 2021-01-01  137.9      178.8  167.0  158.5  155.4  152.0  148.4  147.6  146.9
# 2021-02-01  135.4      167.0  158.5  155.4  152.0  148.4  147.6  146.9  142.5
#
# ...

# %%
rice['last_year'].dropna()
rice=rice.dropna()
x=rice.drop(['Maize'],axis=1)
y=rice['Maize']

# %%
x
# Out:
#             last_year     11     10      9      8      7      6      5      4  \
# Date
# 2012-04-01       98.2  100.8   99.5   99.1   99.6  100.8   96.2   93.2   99.1
# 2012-05-01      100.8   99.5   99.1   99.6  100.8   96.2   93.2   99.1  102.2
# 2012-06-01       99.5   99.1   99.6  100.8   96.2   93.2   99.1  102.2  105.0
# 2012-07-01       99.1   99.6  100.8   96.2   93.2   99.1  102.2  105.0  107.1
# 2012-08-01       99.6  100.8   96.2   93.2   99.1  102.2  105.0  107.1  107.9
# ...               ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2020-10-01      183.6  172.4  175.6  178.8  167.0  158.5  155.4  152.0  148.4
# 2020-11-01      172.4  175.6  178.8  167.0  158.5  155.4  152.0  148.4  147.6
# 2020-12-01      175.6  178.8  167.0  158.5  155.4  152.0  148.4  147.6  146.9
# 2021-01-01      178.8  167.0  158.5  155.4  152.0  148.4  147.6  146.9  142.5
# 2021-02-01      167.0  158.5  155.4  152.0  148.4  147.6  146.9  142.5  137.9
#
# ...

# %%
from sklearn.model_selection import train_test_split
Xtrain, Xtest, Ytrain, Ytest = x[:-6],x[-6:],y[:-6],y[-6:]

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(Xtrain, Ytrain)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(Xtest)
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(Ytest, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(Ytest, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(Ytest, y_pred)))
print('R2: ', metrics.r2_score(Ytest, y_pred))
# Out:
# Mean Absolute Error: 1.0523912596699414
# Mean Squared Error: 1.4583893126773024
# Root Mean Squared Error: 1.2076379062770854
# R2:  0.7132917471800841

# %%
y_pred=model.predict(x)
y1=y.reset_index()
y1
import matplotlib.pyplot as plt
plt.title('Prediction over entire dataset')
plt.xlabel('Number of Months')
plt.ylabel('WPI')
plt.rcParams["figure.figsize"] = (11,6)
plt.plot(y_pred,label='Linear_Regression_Predictions')
plt.plot(y1['Maize'],label='Actual Sales')
plt.legend(loc="upper left")
plt.show()

# %%
Xtest.tail()
# Out:
#             last_year     11     10      9      8      7      6      5      4  \
# Date
# 2020-10-01      183.6  172.4  175.6  178.8  167.0  158.5  155.4  152.0  148.4
# 2020-11-01      172.4  175.6  178.8  167.0  158.5  155.4  152.0  148.4  147.6
# 2020-12-01      175.6  178.8  167.0  158.5  155.4  152.0  148.4  147.6  146.9
# 2021-01-01      178.8  167.0  158.5  155.4  152.0  148.4  147.6  146.9  142.5
# 2021-02-01      167.0  158.5  155.4  152.0  148.4  147.6  146.9  142.5  137.9
#
#                 3      2      1
# Date
# 2020-10-01  147.6  146.9  142.5
# 2020-11-01  146.9  142.5  137.9
# 2020-12-01  142.5  137.9  139.8
# 2021-01-01  137.9  139.8  140.5
# 2021-02-01  139.8  140.5  137.9

# %%
X=Xtest.reset_index()
X=X.drop(['Date'],axis=1)
X
# Out:
#    last_year     11     10      9      8      7      6      5      4      3  \
# 0      185.8  183.6  172.4  175.6  178.8  167.0  158.5  155.4  152.0  148.4
# 1      183.6  172.4  175.6  178.8  167.0  158.5  155.4  152.0  148.4  147.6
# 2      172.4  175.6  178.8  167.0  158.5  155.4  152.0  148.4  147.6  146.9
# 3      175.6  178.8  167.0  158.5  155.4  152.0  148.4  147.6  146.9  142.5
# 4      178.8  167.0  158.5  155.4  152.0  148.4  147.6  146.9  142.5  137.9
# 5      167.0  158.5  155.4  152.0  148.4  147.6  146.9  142.5  137.9  139.8
#
#        2      1
# 0  147.6  146.9
# 1  146.9  142.5
# 2  142.5  137.9
# 3  137.9  139.8
# 4  139.8  140.5
# 5  140.5  137.9

# %%
Ytest
# Out:
# Date
# 2020-09-01    142.5
# 2020-10-01    137.9
# 2020-11-01    139.8
# 2020-12-01    140.5
# 2021-01-01    137.9
# 2021-02-01    135.4
# Freq: MS, Name: Maize, dtype: float64

# %%
X.loc[len(X.index)] =[158.5,155.4,152.0,148.4,147.6,146.9,142.5,137.9,139.8,140.5,137.9,135.4]#march

# %%
model.predict(X)
# Out:
# array([142.37756174, 138.52168092, 138.02994196, 139.69278133,
#        139.18999306, 137.10295862, 134.2947766 ])

# %%
X.loc[len(X.index)] =[155.4,152.0,148.4,147.6,146.9,142.5,137.9,139.8,140.5,137.9,135.4,134.3]

# %%
model.predict(X)#april
# Out:
# array([142.37756174, 138.52168092, 138.02994196, 139.69278133,
#        139.18999306, 137.10295862, 134.2947766 , 132.73524111])

# %%
X.loc[len(X.index)] =[152.0,148.4,147.6,146.9,142.5,137.9,139.8,140.5,137.9,135.4,134.3,132.7]

# %%
model.predict(X)#may
# Out:
# array([142.37756174, 138.52168092, 138.02994196, 139.69278133,
#        139.18999306, 137.10295862, 134.2947766 , 132.73524111,
#        132.33853243])

# %%
X.loc[len(X.index)] =[148.4,147.6,146.9,142.5,137.9,139.8,140.5,137.9,135.4,134.3,132.7,132.3]

# %%
model.predict(X)#june
# Out:
# array([142.37756174, 138.52168092, 138.02994196, 139.69278133,
#        139.18999306, 137.10295862, 134.2947766 , 132.73524111,
#        132.33853243, 132.45657233])

# %%
X.loc[len(X.index)] =[147.6,146.9,142.5,137.9,139.8,140.5,137.9,135.4,134.3,132.7,132.3,132.5]

# %%
model.predict(X)#july
# Out:
# array([142.37756174, 138.52168092, 138.02994196, 139.69278133,
#        139.18999306, 137.10295862, 134.2947766 , 132.73524111,
#        132.33853243, 132.45657233, 132.4198812 ])

# %%
X.loc[len(X.index)] =[146.9,142.5,137.9,139.8,140.5,137.9,135.4,134.3,132.7,132.3,132.5,132.4]

# %%
model.predict(X)#jaugust
# Out:
# array([142.37756174, 138.52168092, 138.02994196, 139.69278133,
#        139.18999306, 137.10295862, 134.2947766 , 132.73524111,
#        132.33853243, 132.45657233, 132.4198812 , 130.97543058])

# %%
X.loc[len(X.index)] =[142.5,137.9,139.8,140.5,137.9,135.4,134.3,132.7,132.3,132.5,132.4,130.4]

# %%
model.predict(X)#september
# Out:
# array([142.37756174, 138.52168092, 138.02994196, 139.69278133,
#        139.18999306, 137.10295862, 134.2947766 , 132.73524111,
#        132.33853243, 132.45657233, 132.4198812 , 130.97543058,
#        129.58503016])

# %%
X.loc[len(X.index)] =[137.9,139.8,140.5,137.9,135.4,134.3,132.7,132.3,132.5,132.4,130.4,129.6]

# %%
model.predict(X)#october
# Out:
# array([142.37756174, 138.52168092, 138.02994196, 139.69278133,
#        139.18999306, 137.10295862, 134.2947766 , 132.73524111,
#        132.33853243, 132.45657233, 132.4198812 , 130.97543058,
#        129.58503016, 129.72825349])

# %%
X.loc[len(X.index)] =[139.8,140.5,137.9,135.4,134.3,132.7,132.3,132.5,132.4,130.4,129.6,129.7]

# %%
model.predict(X)#nov
# Out:
# array([142.37756174, 138.52168092, 138.02994196, 139.69278133,
#        139.18999306, 137.10295862, 134.2947766 , 132.73524111,
#        132.33853243, 132.45657233, 132.4198812 , 130.97543058,
#        129.58503016, 129.72825349, 129.8764184 ])

# %%
X.loc[len(X.index)] =[140.5,137.9,135.4,134.3,132.7,132.3,132.5,132.4,130.4,129.6,129.7,129.9]

# %%
model.predict(X)#dec
# Out:
# array([142.37756174, 138.52168092, 138.02994196, 139.69278133,
#        139.18999306, 137.10295862, 134.2947766 , 132.73524111,
#        132.33853243, 132.45657233, 132.4198812 , 130.97543058,
#        129.58503016, 129.72825349, 129.8764184 , 129.85533165])

# %%
cars = {'Month': ['July','August','September','October','November','December'],
        'WPI': [132.4198812 , 130.97543058,
       129.58503016, 129.72825349, 129.8764184 , 129.85533165]
        }
df = pd.DataFrame(cars)
df.plot(x='Month',y='WPI')

# %% [markdown]
# # URAD

# %%
df=pd.read_csv('rice.csv',index_col='Date',parse_dates=True)
df.tail()
df=df.dropna()
df.index.freq='MS'
rice=df.drop(['Cotton','Rice','Moong','Maize','Apple','Coconut','Coffee','Pigeon Peas'],axis=1)
rice['last_year']=rice['Urad'].shift(+12)
rice['11']=rice['Urad'].shift(+11)
rice['10']=rice['Urad'].shift(+10)
rice['9']=rice['Urad'].shift(+9)
rice['8']=rice['Urad'].shift(+8)
rice['7']=rice['Urad'].shift(+7)
rice['6']=rice['Urad'].shift(+6)
rice['5']=rice['Urad'].shift(+5)
rice['4']=rice['Urad'].shift(+4)
rice['3']=rice['Urad'].shift(+3)
rice['2']=rice['Urad'].shift(+2)
rice['1']=rice['Urad'].shift(+1)

# %%
rice['last_year'].dropna()
rice=rice.dropna()
x=rice.drop(['Urad'],axis=1)
y=rice['Urad']

# %%
from sklearn.model_selection import train_test_split
Xtrain, Xtest, Ytrain, Ytest = x[:-6],x[-6:],y[:-6],y[-6:]

# %%
Ytest
# Out:
# Date
# 2020-09-01    177.6
# 2020-10-01    181.5
# 2020-11-01    188.1
# 2020-12-01    191.0
# 2021-01-01    194.0
# 2021-02-01    196.6
# Freq: MS, Name: Urad, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(Xtrain, Ytrain)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(Xtest)
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(Ytest, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(Ytest, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(Ytest, y_pred)))
print('R2: ', metrics.r2_score(Ytest, y_pred))
# Out:
# Mean Absolute Error: 3.329499826136962
# Mean Squared Error: 12.192517456322046
# Root Mean Squared Error: 3.491778552016443
# R2:  0.7283239902282727

# %%
y_pred=model.predict(x)
y1=y.reset_index()
y1
import matplotlib.pyplot as plt
plt.title('Prediction over entire dataset')
plt.xlabel('Number of Months')
plt.ylabel('WPI')
plt.rcParams["figure.figsize"] = (11,6)
plt.plot(y_pred,label='Linear_Regression_Predictions')
plt.plot(y1['Urad'],label='Actual Sales')
plt.legend(loc="upper left")
plt.show()

# %%
X=Xtest.reset_index()
X=X.drop(['Date'],axis=1)
X
# Out:
#    last_year     11     10      9      8      7      6      5      4      3  \
# 0      133.0  136.1  162.1  177.0  180.9  179.6  176.9  180.6  187.7  184.0
# 1      136.1  162.1  177.0  180.9  179.6  176.9  180.6  187.7  184.0  181.7
# 2      162.1  177.0  180.9  179.6  176.9  180.6  187.7  184.0  181.7  180.9
# 3      177.0  180.9  179.6  176.9  180.6  187.7  184.0  181.7  180.9  177.6
# 4      180.9  179.6  176.9  180.6  187.7  184.0  181.7  180.9  177.6  181.5
# 5      179.6  176.9  180.6  187.7  184.0  181.7  180.9  177.6  181.5  188.1
#
#        2      1
# 0  181.7  180.9
# 1  180.9  177.6
# 2  177.6  181.5
# 3  181.5  188.1
# 4  188.1  191.0
# 5  191.0  194.0

# %%
Ytest
# Out:
# Date
# 2020-09-01    177.6
# 2020-10-01    181.5
# 2020-11-01    188.1
# 2020-12-01    191.0
# 2021-01-01    194.0
# 2021-02-01    196.6
# Freq: MS, Name: Urad, dtype: float64

# %%
X.loc[len(X.index)] =[176.9,180.6,187.7,184.0,181.7,180.9,177.6,181.5,188.1,191.0,194.0,196.6]#march

# %%
model.predict(X)
# Out:
# array([180.94500097, 178.52649919, 183.15161463, 189.31057893,
#        191.24419279, 192.33511648, 196.01486234])

# %%
X.loc[len(X.index)] =[180.6,187.7,184.0,181.7,180.9,177.6,181.5,188.1,191.0,194.0,196.6,196.0]#april

# %%
model.predict(X)
# Out:
# array([180.94500097, 178.52649919, 183.15161463, 189.31057893,
#        191.24419279, 192.33511648, 196.01486234, 195.40949717])

# %%
X.loc[len(X.index)] =[187.7,184.0,181.7,180.9,177.6,181.5,188.1,191.0,194.0,196.6,196.0,195.4]#may

# %%
model.predict(X)
# Out:
# array([180.94500097, 178.52649919, 183.15161463, 189.31057893,
#        191.24419279, 192.33511648, 196.01486234, 195.40949717,
#        193.02407278])

# %%
X.loc[len(X.index)] =[184.0,181.7,180.9,177.6,181.5,188.1,191.0,194.0,196.6,196.0,195.4,193.0]#june

# %%
model.predict(X)
# Out:
# array([180.94500097, 178.52649919, 183.15161463, 189.31057893,
#        191.24419279, 192.33511648, 196.01486234, 195.40949717,
#        193.02407278, 189.66116518])

# %%
X.loc[len(X.index)] =[181.7,180.9,177.6,181.5,188.1,191.0,194.0,196.6,196.0,195.4,193.0,189.7]#july

# %%
model.predict(X)
# Out:
# array([180.94500097, 178.52649919, 183.15161463, 189.31057893,
#        191.24419279, 192.33511648, 196.01486234, 195.40949717,
#        193.02407278, 189.66116518, 187.20759172])

# %%
X.loc[len(X.index)] =[180.9,177.6,181.5,188.1,191.0,194.0,196.6,196.0,195.4,193.0,189.7,187.2]#aug

# %%
model.predict(X)
# Out:
# array([180.94500097, 178.52649919, 183.15161463, 189.31057893,
#        191.24419279, 192.33511648, 196.01486234, 195.40949717,
#        193.02407278, 189.66116518, 187.20759172, 184.4145133 ])

# %%
X.loc[len(X.index)] =[177.6,181.5,188.1,191.0,194.0,196.6,196.0,195.4,193.0,189.7,187.2,184.4]#sept

# %%
model.predict(X)
# Out:
# array([180.94500097, 178.52649919, 183.15161463, 189.31057893,
#        191.24419279, 192.33511648, 196.01486234, 195.40949717,
#        193.02407278, 189.66116518, 187.20759172, 184.4145133 ,
#        181.64829718])

# %%
X.loc[len(X.index)] =[181.5,188.1,191.0,194.0,196.6,196.0,195.4,193.0,189.7,187.2,184.4,181.6]#oct

# %%
model.predict(X)
# Out:
# array([180.94500097, 178.52649919, 183.15161463, 189.31057893,
#        191.24419279, 192.33511648, 196.01486234, 195.40949717,
#        193.02407278, 189.66116518, 187.20759172, 184.4145133 ,
#        181.64829718, 178.96618366])

# %%
X.loc[len(X.index)] =[188.1,191.0,194.0,196.6,196.0,195.4,193.0,189.7,187.2,184.4,181.6,179.0]#nov

# %%
model.predict(X)
# Out:
# array([180.94500097, 178.52649919, 183.15161463, 189.31057893,
#        191.24419279, 192.33511648, 196.01486234, 195.40949717,
#        193.02407278, 189.66116518, 187.20759172, 184.4145133 ,
#        181.64829718, 178.96618366, 175.63879798])

# %%
X.loc[len(X.index)] =[189.31057893,
       191.24419279, 192.33511648, 196.01486234, 195.40949717,
       193.02407278, 189.66116518, 187.20759172, 184.4145133 ,
       181.64829718, 178.96618366, 175.63879798]#dec

# %%
model.predict(X)
# Out:
# array([180.94500097, 178.52649919, 183.15161463, 189.31057893,
#        191.24419279, 192.33511648, 196.01486234, 195.40949717,
#        193.02407278, 189.66116518, 187.20759172, 184.4145133 ,
#        181.64829718, 178.96618366, 175.63879798, 172.04322665,
#        172.18941244])

# %%
cars = {'Month': ['July','August','September','October','November','December'],
        'WPI': [187.20759172, 184.4145133 ,
       181.64829718, 178.96618366, 175.63879798, 172.04322665]
        }
df = pd.DataFrame(cars)
df.plot(x='Month',y='WPI')

# %%
Ytest.tail(20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d6d78855b774> in <module>
# ----> 1 Ytest.tail(20)
#
# NameError: name 'Ytest' is not defined

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
rice1=seasonal_decompose(df['Urad'])
rice1.plot()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
rice1=seasonal_decompose(df['Maize'])
rice1.plot()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
rice1=seasonal_decompose(df['Rice'])
rice1.plot()

# %%
train=rice.iloc[:107]
test=rice.iloc[107:]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
scaler.fit(train)
scaled_train = scaler.fit_transform(train)
scaled_test = scaler.fit_transform(test)

# %%
from keras.preprocessing.sequence import TimeseriesGenerator

# %%
# define generator
n_input = 3
n_features = 1
generator = TimeseriesGenerator(scaled_train[1:], scaled_train[1:], length=n_input, batch_size=1)

# %%
X,y = generator[0]
print(f'Given the Array: \n{X.flatten()}')
print(f'Predict this y: \n {y}')
# Out:
# Given the Array:
# [0.02147239 0.0291411  0.0398773 ]
# Predict this y:
#  [[0.05828221]]

# %%
n_input = 12
n_features = 1
generator12 = TimeseriesGenerator(scaled_train, scaled_train, length=n_input, batch_size=1)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

# %%
# define model
model = Sequential()
model.add(LSTM(50, activation='relu', input_shape=(n_input, n_features)))
model.add(LSTM(50, activation='relu'))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-525-97e2162980ec> in <module>
#       2 model = Sequential()
#       3 model.add(LSTM(50, activation='relu', input_shape=(n_input, n_features)))
# ----> 4 model.add(LSTM(50, activation='relu'))
#       5 model.add(Dense(1))
#       6 model.compile(optimizer='adam', loss='mse')
#
# ~\anaconda3\lib\site-packages\tensorflow\python\training\tracking\base.py in _method_wrapper(self, *args, **kwargs)
#     455     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     456     try:
# --> 457       result = method(self, *args, **kwargs)
#     458     finally:
#     459       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\sequential.py in add(self, layer)
# ...

# %%
model.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm_5 (LSTM)                (None, 100)               40800
# _________________________________________________________________
# dense_17 (Dense)             (None, 1)                 101
# _________________________________________________________________
# dense_18 (Dense)             (None, 2)                 4
# _________________________________________________________________
# dense_19 (Dense)             (None, 3)                 9
# ...
# Total params: 40,914
# Trainable params: 40,914
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(generator,epochs=5)
# Out:
# Epoch 1/5
# 103/103 [==============================] - 0s 2ms/step - loss: 0.1093
# Epoch 2/5
# 103/103 [==============================] - 0s 2ms/step - loss: 0.0033
# Epoch 3/5
# 103/103 [==============================] - 0s 2ms/step - loss: 0.0013
# Epoch 4/5
# 103/103 [==============================] - 0s 2ms/step - loss: 0.0012
# Epoch 5/5
# 103/103 [==============================] - 0s 2ms/step - loss: 0.0014

# %%
import matplotlib.pyplot as plt
loss_per_epoch = model.history.history['loss']
plt.plot(range(len(loss_per_epoch)),loss_per_epoch)

# %%
last_train_batch = scaled_train[-12:]

# %%
last_train_batch = last_train_batch.reshape((1, n_input, n_features))

# %%
model.predict(last_train_batch)
# Out:
# array([[-92.41937]], dtype=float32)

# %%
scaled_test[0]
# Out:
# array([0., 0.])

# %%
test_predictions = []

first_eval_batch = scaled_train[-n_input:]
current_batch = first_eval_batch.reshape((1, n_input, n_features))

for i in range(len(test)):
    
    # get the prediction value for the first batch
    current_pred = model.predict(current_batch)[0]
    
    # append the prediction into the array
    test_predictions.append(current_pred) 
    
    # use the prediction to update the batch and remove the first value
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)

# %%
true_predictions = scaler.inverse_transform(test_predictions)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-518-0efe543c9183> in <module>
# ----> 1 true_predictions = scaler.inverse_transform(test_predictions)
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in inverse_transform(self, X)
#     430                         force_all_finite="allow-nan")
#     431
# --> 432         X -= self.min_
#     433         X /= self.scale_
#     434         return X
#
# ValueError: non-broadcastable output operand with shape (12,1) doesn't match the broadcast shape (12,2)

# %%
test['Predictions'] = true_predictions
# Out:
# <ipython-input-519-920b79c3c314>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Predictions'] = true_predictions

# %%
test.plot(figsize=(14,5))

# %%
cotton=df.drop(['Rice','Maize','Moong','Urad','Apple','Coconut','Coffee','Pigeon Peas'],axis=1)
cotton['last_year']=cotton['Cotton'].shift(+12)
cotton['11']=cotton['Cotton'].shift(+11)
cotton['10']=cotton['Cotton'].shift(+10)
cotton['9']=cotton['Cotton'].shift(+9)
cotton['8']=cotton['Cotton'].shift(+8)
cotton['7']=cotton['Cotton'].shift(+7)
cotton['6']=cotton['Cotton'].shift(+6)
cotton['5']=cotton['Cotton'].shift(+5)
cotton['4']=cotton['Cotton'].shift(+4)
cotton['3']=cotton['Cotton'].shift(+3)
cotton['2']=cotton['Cotton'].shift(+2)
cotton['1']=cotton['Cotton'].shift(+1)
cotton
# Out:
#             Cotton  last_year     11     10      9      8      7      6  \
# Date
# 2011-01-04   137.6        NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2011-01-05   113.9        NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2011-01-06   105.8        NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2011-01-07    92.5        NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2011-01-08    96.6        NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ...            ...        ...    ...    ...    ...    ...    ...    ...
# 2020-01-10    99.6      113.6  109.6  108.9  109.0  107.5  107.0  106.8
# 2020-01-11   105.4      109.6  108.9  109.0  107.5  107.0  106.8  104.4
# 2020-01-12   107.9      108.9  109.0  107.5  107.0  106.8  104.4  106.1
# 2021-01-01   109.8      109.0  107.5  107.0  106.8  104.4  106.1  106.4
# 2021-01-02   113.9      107.5  107.0  106.8  104.4  106.1  106.4   92.0
#
#                 5      4      3      2      1
# Date
# ...

# %%
cotton=cotton.dropna()

# %%
x=cotton.drop(['Cotton'],axis=1)

# %%
y=cotton['Cotton']

# %%
from sklearn.model_selection import train_test_split
Xtrain, Xtest, Ytrain, Ytest = x[:-12],x[-12:],y[:-12],y[-12:]

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(Xtrain, Ytrain)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(Xtest)
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(Ytest, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(Ytest, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(Ytest, y_pred)))
print('R2: ', metrics.r2_score(Ytest, y_pred))
# Out:
# Mean Absolute Error: 3.7224053281979934
# Mean Squared Error: 30.725319074721
# Root Mean Squared Error: 5.54304240239248
# R2:  0.12398831308324998

# %%
from sklearn.tree import DecisionTreeRegressor 
dtmodel = DecisionTreeRegressor()
dtmodel.fit(Xtrain, Ytrain)
# Out:
# DecisionTreeRegressor()

# %%
y_pred=dtmodel.predict(Xtest)
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(Ytest, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(Ytest, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(Ytest, y_pred)))
print('R2: ', metrics.r2_score(Ytest, y_pred))
# Out:
# Mean Absolute Error: 5.033333333333331
# Mean Squared Error: 42.13999999999998
# Root Mean Squared Error: 6.491532946846991
# R2:  -0.2014564404326542

# %%
from sklearn.ensemble import RandomForestRegressor 
dtmodel = RandomForestRegressor()
dtmodel.fit(Xtrain, Ytrain)
# Out:
# RandomForestRegressor()

# %%
y_pred=dtmodel.predict(Xtest)
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(Ytest, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(Ytest, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(Ytest, y_pred)))
print('R2: ', metrics.r2_score(Ytest, y_pred))
# Out:
# Mean Absolute Error: 3.4747500000000087
# Mean Squared Error: 24.99865274999989
# Root Mean Squared Error: 4.999865273184858
# R2:  0.28726169082518116

# %% [markdown]
# # Linear Regression

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,7))
plt.title("Price of Rice")
plt.scatter(x=df['Date'],y=df['Rice'])
plt.ylabel('Price(in rupees)')
plt.xlabel('Dates')
plt.show()

# %%
train=df[:107]
test=df[107:]
train.tail()
# Out:
#           Date   Rice  Cotton  Maize  Moong   Urad  Apple  Coconut  Coffee  \
# 102  1/10/2019  162.7   113.6  183.6  139.7  136.1   90.3    204.4    94.6
# 103  1/11/2019  162.1   109.6  172.4  146.7  162.1   83.5    210.1    93.6
# 104  1/12/2019  162.0   108.9  175.6  149.6  177.0   87.0    207.3    95.1
# 105   1/1/2020  162.3   109.0  178.8  151.3  180.9   91.6    210.7    95.1
# 106   1/2/2020  162.3   107.5  167.0  156.6  179.6   98.9    220.1    95.1
#
#      Pigeon Peas
# 102        150.4
# 103        153.6
# 104        154.6
# 105        152.0
# 106        152.8

# %%
test
# Out:
#           Date   Rice  Cotton  Maize  Moong   Urad
# 107   1/3/2020  159.3   107.0  158.5  162.0  176.9
# 108   1/4/2020  162.7   106.8  155.4  174.2  180.6
# 109   1/5/2020  163.1   104.4  152.0  179.7  187.7
# 110   1/6/2020  165.6   106.1  148.4  176.1  184.0
# 111   1/7/2020  165.8   106.4  147.6  173.6  181.7
# 112   1/8/2020  165.4    92.0  146.9  170.4  180.9
# 113   1/9/2020  165.0    94.8  142.5  164.3  177.6
# 114  1/10/2020  163.7    99.6  137.9  162.6  181.5
# 115  1/11/2020  163.1   105.4  139.8  165.1  188.1
# 116  1/12/2020  162.2   107.9  140.5  168.5  191.0
# 117   1/1/2021  162.1   109.8  137.9  166.9  194.0
# 118   1/2/2021  161.7   113.9  135.4  169.7  196.6

# %%
from sklearn.preprocessing import PolynomialFeatures
import numpy as np
X_train = np.array(train.index).reshape(-1, 1)
y_train = train['Rice']
X_test = np.array(test.index).reshape(-1, 1)
y_test = test['Rice']

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
# Fit linear model using the train data set
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
plt.figure(1, figsize=(16,10))
plt.title('Linear Regression | Price vs Time | Training Dataset')
plt.scatter(X_train, y_train, edgecolor='w', label='train Price')
plt.scatter(X_test, y_test, color='orange', label='text Price')
plt.plot(X_train, model.predict(X_train), color='r', label='Predicted Price using Linear Regression')
plt.plot(X_test, model.predict(X_test), color='green', label='Predicted Price')
plt.xlabel('Integer Date')
plt.ylabel('RicePrice')
plt.legend()
plt.show()

# %%
y_pred=model.predict(X_test)

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 6.797508767804987
# Mean Squared Error: 53.818384571455745
# Root Mean Squared Error: 7.336101455913471

# %% [markdown]
# # Polynomic Regression

# %%
poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(X_train)
poly.fit(X_poly,y_train)
lr_2=LinearRegression()
lr_2.fit(X_poly,y_train)
# Out:
# LinearRegression()

# %%
plt.figure(1, figsize=(16,10))
plt.title('Regression degree 2| Price vs Time | Training Dataset')
plt.scatter(X_train, y_train, edgecolor='w', label='Actual Price')
plt.plot(X_train, lr_2.predict(poly.fit_transform(X_train)), color='r', label='Predicted Price using Linear Regression')
plt.scatter(X_test, y_test, color='orange', label='Actual Price')
plt.plot(X_test, lr_2.predict(poly.transform(X_test)), color='green', label='Predicted Price')
plt.xlabel('Integer Date')
plt.ylabel('RicePrice')
plt.legend()
plt.show()

# %%
y_pred=lr_2.predict(poly.transform(X_test))

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 2.9016240527508708
# Mean Squared Error: 11.642559266051189
# Root Mean Squared Error: 3.412119468314553

# %%
#setting index as date
#df1['Date'] = pd.to_datetime(df1.Date,format='%d/%m/%y')
#df1.index = df1['Date']

#plot
#plt.figure(figsize=(16,8))
#plt.title("Price of Rice")
#plt.plot(df['Rice'])
#plt.ylabel('Price(in rupees)')
#plt.xlabel('Dates')

# %%
#setting index as date
#df1['Date'] = pd.to_datetime(df1.Date,format='%d/%m/%y')
#df1.index = df1['Date']

#plot
#plt.figure(figsize=(16,8))
#plt.title("Price of Rice")
#plt.plot(df['Rice'])
#plt.ylabel('Price(in rupees)')
#plt.xlabel('Dates')

# %% [markdown]
# # Cotton

# %% [markdown]
# # ARIMA

# %%
import pandas as pd
df=pd.read_csv('rice.csv',index_col='Date',parse_dates=True)
df=df.dropna()
print('Shape of data',df.shape)
df.head()
df
# Out:
# Shape of data (119, 9)
#              Rice  Cotton  Maize  Moong   Urad  Apple  Coconut  Coffee  \
# Date
# 2011-01-04   97.5   137.6   98.2  104.6  105.3  102.9    102.4    87.8
# 2011-01-05   98.9   113.9  100.8  103.8  105.5  110.8    104.5   101.3
# 2011-01-06   99.4   105.8   99.5  102.2  105.5  111.5    107.0   102.2
# 2011-01-07  100.1    92.5   99.1  100.7  101.7  102.5    102.1   102.1
# 2011-01-08  101.3    96.6   99.6  100.5   99.6   98.8    102.0    99.5
# ...           ...     ...    ...    ...    ...    ...      ...     ...
# 2020-01-10  163.7    99.6  137.9  162.6  181.5   95.0    231.3   108.0
# 2020-01-11  163.1   105.4  139.8  165.1  188.1   94.7    232.2   104.5
# 2020-01-12  162.2   107.9  140.5  168.5  191.0  103.1    240.6   102.6
# 2021-01-01  162.1   109.8  137.9  166.9  194.0  110.0    240.4   100.1
# 2021-01-02  161.7   113.9  135.4  169.7  196.6  121.8    237.3    95.0
#
#             Pigeon Peas
# Date
# 2011-01-04        107.3
# 2011-01-05        103.8
# ...

# %%
train=df['Rice'][:107]
test=df['Rice'][107:]

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
import numpy as np
model = Sequential()
model.add(Dense(100, activation='relu'))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')
a = np.array(train).reshape(1,-1)
b = np.array(test).reshape(1,-1)

# %%
model.fit(a,b, epochs=20, verbose=0)

# %%
pred = model.predict(a, verbose=0)
print(pred)
print(test)
# Out:
# [[163.30833]]
# 107    159.3
# 108    162.7
# 109    163.1
# 110    165.6
# 111    165.8
# 112    165.4
# 113    165.0
# 114    163.7
# 115    163.1
# 116    162.2
# 117    162.1
# 118    161.7
# Name: Rice, dtype: float64

# %%
df['Cotton'].plot(figsize=(12,5))

# %%
from statsmodels.tsa.stattools import adfuller
def ad_test(dataset):
     dftest = adfuller(dataset, autolag = 'AIC')
     print("1. ADF : ",dftest[0])
     print("2. P-Value : ", dftest[1])
     print("3. Num Of Lags : ", dftest[2])
     print("4. Num Of Observations Used For ADF Regression:",      dftest[3])
     print("5. Critical Values :")
     for key, val in dftest[4].items():
         print("\t",key, ": ", val)
ad_test(df['Cotton'])
# Out:
# 1. ADF :  -2.7515055564162996
# 2. P-Value :  0.06554167864036352
# 3. Num Of Lags :  2
# 4. Num Of Observations Used For ADF Regression: 116
# 5. Critical Values :
# 	 1% :  -3.4880216384691867
# 	 5% :  -2.8867966864160075
# 	 10% :  -2.5802408234244947

# %%
df['Sales First Difference'] = df['Cotton'] - df['Cotton'].shift(1)
df['Seasonal First Difference']=df['Cotton']-df['Cotton'].shift(12)
df.head()
# Out:
#              Rice  Cotton  Maize  Moong   Urad  Sales First Difference  \
# Date
# 2011-01-04   97.5   137.6   98.2  104.6  105.3                     NaN
# 2011-01-05   98.9   113.9  100.8  103.8  105.5                   -23.7
# 2011-01-06   99.4   105.8   99.5  102.2  105.5                    -8.1
# 2011-01-07  100.1    92.5   99.1  100.7  101.7                   -13.3
# 2011-01-08  101.3    96.6   99.6  100.5   99.6                     4.1
#
#             Seasonal First Difference
# Date
# 2011-01-04                        NaN
# 2011-01-05                        NaN
# 2011-01-06                        NaN
# 2011-01-07                        NaN
# 2011-01-08                        NaN

# %%
ad_test(df['Seasonal First Difference'].dropna())
# Out:
# 1. ADF :  -3.7430553786014995
# 2. P-Value :  0.0035467245929810287
# 3. Num Of Lags :  13
# 4. Num Of Observations Used For ADF Regression: 93
# 5. Critical Values :
# 	 1% :  -3.502704609582561
# 	 5% :  -2.8931578098779522
# 	 10% :  -2.583636712914788

# %%
df['Seasonal First Difference'].plot()

# %%
from pandas.plotting import autocorrelation_plot
autocorrelation_plot(df['Cotton'])
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
import statsmodels.api as sm
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(df['Seasonal First Difference'].dropna(),lags=40,ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(df['Seasonal First Difference'].dropna(),lags=40,ax=ax2)

# %%
# For non-seasonal data
#p=1, d=1, q=0 or 1

from statsmodels.tsa.arima_model import ARIMA
model=ARIMA(df['Cotton'],order=(1,1,1))
model_fit=model.fit()
model_fit.summary()
# Out:
# C:\Users\pabba\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:216: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\Users\pabba\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:216: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              ARIMA Model Results
# ...
# Dep. Variable:               D.Cotton   No. Observations:                  118
# Model:                 ARIMA(1, 1, 1)   Log Likelihood                -340.819
# Method:                       css-mle   S.D. of innovations              4.341
# ...

# %%
df['forecast']=model_fit.predict(start=90,end=103,dynamic=True)
df[['Cotton','forecast']].plot(figsize=(12,8))

# %%
import statsmodels.api as sm
model=sm.tsa.statespace.SARIMAX(df['Cotton'],order=(1, 1, 1),seasonal_order=(1,1,1,12))
results=model.fit()
df['forecast']=results.predict(start=90,end=118,dynamic=True)
pred=df['forecast'].iloc[90:119]
print(metrics.mean_absolute_error(df['Cotton'].iloc[90:119], pred))
#df[['Cotton','forecast']].plot(figsize=(12,8))
print('R2: ', metrics.r2_score(df['Cotton'].iloc[90:119], pred))
# Out:
# C:\Users\pabba\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:216: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# C:\Users\pabba\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:216: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   warnings.warn('A date index has been provided, but it has no'
# 10.052301149648402
# R2:  -1.2275410777156215

# %%
print(df.shape)
train=df.iloc[:-30]
test=df.iloc[-30:]
print(train.shape,test.shape)
# Out:
# (119, 7)
# (89, 7) (30, 7)

# %% [markdown]
# # REGRESSION

# %%
plt.figure(figsize=(20,7))
plt.title("Price of Rice")
plt.plot(x=df['Date'],y=df['Cotton'])
plt.ylabel('Price(in rupees)')
plt.xlabel('Dates')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-312-13ece4a3de70> in <module>
# ----> 1 plt.figure(figsize=(20,7))
#       2 plt.title("Price of Rice")
#       3 plt.plot(x=df['Date'],y=df['Cotton'])
#       4 plt.ylabel('Price(in rupees)')
#       5 plt.xlabel('Dates')
#
# NameError: name 'plt' is not defined

# %%
X_train = np.array(train.index).reshape(-1, 1)
y_train = train['Cotton']
X_test = np.array(test.index).reshape(-1, 1)
y_test = test['Cotton']
poly = PolynomialFeatures(degree=11)
X_poly = poly.fit_transform(X_train)
poly.fit(X_poly,y_train)
lr_2=LinearRegression()
lr_2.fit(X_poly,y_train)
# Out:
# LinearRegression()

# %%
plt.figure(figsize=(20,7))
plt.title('Linear Regression degree 2| Price vs Time | Training Dataset')
plt.scatter(X_train, y_train, edgecolor='w', label='Actual Price')
plt.scatter(X_train, lr_2.predict(poly.fit_transform(X_train)), color='r', label='Predicted Price using Linear Regression')
#plt.scatter(X_test, y_test, color='orange', label='Actual Price')
#plt.scatter(X_test, lr_2.predict(poly.transform(X_test)), color='green', label='Predicted Price')
plt.xlabel('Integer Date')
plt.ylabel('RicePrice')
plt.legend()
plt.show()

# %%
y_pred=lr_2.predict(poly.transform(X_test))
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print('R2: ', metrics.r2_score(y_test, y_pred))
# Out:
# Mean Absolute Error: 16651.91007115739
# Mean Squared Error: 852905028.176227
# Root Mean Squared Error: 29204.537801105962
# R2:  -11375706.26867567

# %% [markdown]
# # Maize

# %%
plt.figure(figsize=(20,7))
plt.title("Price of Rice")
plt.scatter(x=df['Date'],y=df['Maize'])
plt.ylabel('Price(in rupees)')
plt.xlabel('Dates')
plt.show()

# %%
X_train = np.array(train.index).reshape(-1, 1)
y_train = train['Maize']
X_test = np.array(test.index).reshape(-1, 1)
y_test = test['Maize']
poly = PolynomialFeatures(degree=9)
X_poly = poly.fit_transform(X_train)
poly.fit(X_poly,y_train)
lr_2=LinearRegression()
lr_2.fit(X_poly,y_train)
plt.figure(figsize=(20,7))
plt.title('Linear Regression degree 2| Price vs Time | Training Dataset')
plt.scatter(X_train, y_train, edgecolor='w', label='Actual Price')
plt.scatter(X_train, lr_2.predict(poly.fit_transform(X_train)), color='r', label='Predicted Price using Linear Regression')
plt.scatter(X_test, y_test, color='orange', label='Actual Price')
#plt.scatter(X_test, lr_2.predict(poly.transform(X_test)), color='green', label='Predicted Price')
plt.xlabel('Integer Date')
plt.ylabel('RicePrice')
plt.legend()
plt.show()

# %%
y_pred=lr_2.predict(poly.transform(X_test))
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print('R2: ', metrics.r2_score(y_test, y_pred))
# Out:
# Mean Absolute Error: 1247.3545500163798
# Mean Squared Error: 4641177.389141237
# Root Mean Squared Error: 2154.3392001124703
# R2:  -14148.612314719585

# %% [markdown]
# # Moong Dal

# %%
plt.figure(figsize=(20,7))
plt.title("Price of Rice")
plt.scatter(x=df['Date'],y=df['Moong'])
plt.ylabel('Price(in rupees)')
plt.xlabel('Dates')
plt.show()

# %%
X_train = np.array(train.index).reshape(-1, 1)
y_train = train['Moong']
X_test = np.array(test.index).reshape(-1, 1)
y_test = test['Moong']
poly = PolynomialFeatures(degree=9)
X_poly = poly.fit_transform(X_train)
poly.fit(X_poly,y_train)
lr_2=LinearRegression()
lr_2.fit(X_poly,y_train)
plt.figure(figsize=(20,7))
plt.title('Linear Regression degree 2| Price vs Time | Training Dataset')
plt.scatter(X_train, y_train, edgecolor='w', label='Actual Price')
plt.scatter(X_train, lr_2.predict(poly.fit_transform(X_train)), color='r', label='Predicted Price using Linear Regression')
#plt.scatter(X_test, y_test, color='orange', label='Actual Price')
#plt.scatter(X_test, lr_2.predict(poly.transform(X_test)), color='green', label='Predicted Price')
plt.xlabel('Integer Date')
plt.ylabel('RicePrice')
plt.legend()
plt.show()

# %%
y_pred=lr_2.predict(poly.transform(X_test))
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print('R2: ', metrics.r2_score(y_test, y_pred))
# Out:
# Mean Absolute Error: 1722.500358175346
# Mean Squared Error: 7097920.1246121535
# Root Mean Squared Error: 2664.1922086463946
# R2:  -18558.50051932711

# %% [markdown]
# # Urad Dal

# %% [markdown]
# # Polynomic Regression

# %%
plt.figure(figsize=(20,7))
plt.title("Price of Rice")
plt.scatter(x=df['Date'],y=df['Urad'])
plt.ylabel('Price(in rupees)')
plt.xlabel('Dates')
plt.show()

# %%
X_train = np.array(train.index).reshape(-1, 1)
y_train = train['Urad']
X_test = np.array(test.index).reshape(-1, 1)
y_test = test['Urad']

# %%
poly = PolynomialFeatures(degree=9)
X_poly = poly.fit_transform(X_train)
poly.fit(X_poly,y_train)
lr_2=LinearRegression()
lr_2.fit(X_poly,y_train)
# Out:
# LinearRegression()

# %%
plt.figure(1, figsize=(16,10))
plt.title('Linear Regression degree 9| Price vs Time | Training Dataset')
plt.scatter(X_train, y_train, label='Actual Price')
plt.scatter(X_train, lr_2.predict(poly.fit_transform(X_train)), color='r', label='Predicted train Price using Linear Regression')
plt.scatter(X_test, y_test, color='g', label='Actual Test Price')
#plt.scatter(X_test, lr_2.predict(poly.transform(X_test)), color='orange', label='Predicted test Price using Linear Regression')
plt.xlabel('Integer Date')
plt.ylabel('URAD PRICE')
plt.legend()
plt.show()

# %%
y_pred=lr_2.predict(poly.transform(X_test))
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print('R2: ', metrics.r2_score(y_test, y_pred))
# Out:
# Mean Absolute Error: 2840.350722653817
# Mean Squared Error: 18601208.275949553
# Root Mean Squared Error: 4312.911809433338
# R2:  -30478.606399506487

# %% [markdown]
# # Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor 
dtmodel = DecisionTreeRegressor()
dtmodel.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
plt.figure(1, figsize=(16,10))
plt.title('Decision Tree Regressor | Price vs Time | Training Dataset')
plt.scatter(X_train, y_train, edgecolor='w', label='Actual Price')
plt.scatter(X_train, dtmodel.predict(X_train), color='r', label='Predicted Price')
plt.xlabel('Integer Date')
plt.ylabel('RicePrice')
plt.legend()
plt.show()

# %%
y_pred=dtmodel.predict(poly.transform(X_test))
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-613-05aa410ac61c> in <module>
# ----> 1 y_pred=dtmodel.predict(poly.transform(X_test))
#       2 print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
#       3 print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
#       4 print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in predict(self, X, check_input)
#     425         """
#     426         check_is_fitted(self)
# --> 427         X = self._validate_X_predict(X, check_input)
#     428         proba = self.tree_.predict(X)
#     429         n_samples = X.shape[0]
#
# ~\anaconda3\lib\site-packages\sklearn\tree\_classes.py in _validate_X_predict(self, X, check_input)
#     394         n_features = X.shape[1]
# ...

# %% [markdown]
# # Lasso Regression

# %%
from sklearn.linear_model import Lasso
from sklearn.model_selection import GridSearchCV
lasso=Lasso()
parameters={'alpha':[1e-150,1e-100,1e-50,1e-30,1e-25,1e-20,1e-15,1e-10,1e-8,1e-3,1e-2,1,5,10,20,30,35,40,45,50,55,100,200,300]}
lasso_regressor=GridSearchCV(lasso,parameters,scoring='neg_mean_squared_error',cv=5)

lasso_regressor.fit(X_train,y_train)
print(lasso_regressor.best_params_)
print(lasso_regressor.best_score_)
# Out:
# C:\Users\pabba\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1024.220782073031, tolerance: 3.0040081052631575
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\pabba\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1109.0726136255441, tolerance: 3.070753792207792
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\pabba\anaconda3\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:529: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1101.432240599753, tolerance: 3.2501281298701294
#   model = cd_fast.enet_coordinate_descent(
# ...

# %%
y_pred=lasso_regressor.predict(X_test)
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print('R2: ', metrics.r2_score(y_test, y_pred))
# Out:
# Mean Absolute Error: 4.142654531848926
# Mean Squared Error: 31.07187503863966
# Root Mean Squared Error: 5.5742151948628305
# R2:  0.9244510926070597

# %%
from sklearn import linear_model
las = linear_model.Lasso(alpha=30,max_iter=100)
las.fit(X_train, y_train)
# Out:
# Lasso(alpha=30, max_iter=100)

# %%
plt.figure(1, figsize=(16,10))
plt.title('Lasso Regression | Price vs Time | Training Dataset')
plt.scatter(X_train, y_train, edgecolor='w', label='Actual Price')
plt.plot(X_train, las.predict(X_train), color='r', label='Predicted Price using Linear Regression')
plt.xlabel('Integer Date')
plt.ylabel('RicePrice')
plt.legend()
plt.show()

# %%
y_pred=las.predict(X_test)
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print('R2: ', metrics.r2_score(y_test, y_pred))
# Out:
# Mean Absolute Error: 4.197987737168941
# Mean Squared Error: 33.51649044605903
# Root Mean Squared Error: 5.789342833695292
# R2:  0.8996455455914291

# %% [markdown]
# # Ridge Regression

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV

ridge=Ridge()
parameters={'alpha':[1e-100,1e-15,1e-10,1e-8,1e-3,1e-2,1,5,10,20,30,35,40,45,50,55,100,200,300]}
ridge_regressor=GridSearchCV(ridge,parameters,scoring='neg_mean_squared_error',cv=5)
ridge_regressor.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [1e-100, 1e-15, 1e-10, 1e-08, 0.001, 0.01, 1,
#                                    5, 10, 20, 30, 35, 40, 45, 50, 55, 100, 200,
#                                    300]},
#              scoring='neg_mean_squared_error')

# %%
print(ridge_regressor.best_params_)
print(ridge_regressor.best_score_)
# Out:
# {'alpha': 1e-100}
# -27.410608032865564

# %%
ridge = linear_model.Ridge(alpha=100)
ridge.fit(X_train, y_train)
# Out:
# Ridge(alpha=100)

# %%
plt.figure(1, figsize=(16,10))
plt.title('Linear Regression | Price vs Time | Training Dataset')
plt.scatter(X_train, y_train, edgecolor='w', label='Actual Price')
plt.plot(X_train, ridge_regressor.predict(X_train), color='r', label='Predicted Price using Ridge Regression')
plt.xlabel('Integer Date')
plt.ylabel('RicePrice')
plt.legend()
plt.show()

# %%
y_pred=ridge_regressor.predict(X_test)
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
print('R2: ', metrics.r2_score(y_test, y_pred))
# Out:
# Mean Absolute Error: 3.954818184230696
# Mean Squared Error: 32.72416774017332
# Root Mean Squared Error: 5.720504150874582
# R2:  0.9142876532950903

# %%
from sklearn.tree import DecisionTreeRegressor 
dtmodel = DecisionTreeRegressor()
dtmodel.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
plt.figure(1, figsize=(16,10))
plt.title('Decision Tree Regressor | Price vs Time | Training Dataset')
plt.scatter(X_train, y_train, edgecolor='w', label='Actual Price')
plt.scatter(X_train, dtmodel.predict(X_train), color='r', label='Predicted Price')
plt.xlabel('Integer Date')
plt.ylabel('RicePrice')
plt.legend()
plt.show()

# %%
plt.figure(1, figsize=(16,10))
plt.title('Linear Regression | Price vs Time | Test Dataset')
plt.scatter(X_test, y_test, edgecolor='w', label='Actual Price')
plt.scatter(X_test, dtmodel.predict(X_test), color='r', label='Predicted Price')
plt.xlabel('Integer Date')
plt.ylabel('RicePrice')
plt.legend()
plt.show()

# %%
y_pred=dtmodel.predict(X_test)

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 0.2550000000000011
# Mean Squared Error: 0.3595000000000016
# Root Mean Squared Error: 0.599583188556852

# %%
print('R2: ', metrics.r2_score(y_test, y_pred))
# Out:
# R2:  0.9986881092981941

# %%
from sklearn.svm import SVR
SVmodel = SVR()
SVmodel.fit(X_train, y_train)
# Out:
# SVR()

# %%
plt.figure(1, figsize=(16,10))
plt.title('Linear Regression | Price vs Time | Test Dataset')
plt.scatter(X_test, y_test, edgecolor='w', label='Actual Price')
plt.scatter(X_test, SVmodel.predict(X_test), color='r', label='Predicted Price')
plt.xlabel('Integer Date')
plt.ylabel('RicePrice')
plt.legend()
plt.show()

# %%
from sklearn import metrics
y_pred=SVmodel.predict(X_test)
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))  
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))  
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 5.16270026979465
# Mean Squared Error: 66.79467486317137
# Root Mean Squared Error: 8.17280091909569

# %%
print('R2: ', metrics.r2_score(y_test, y_pred))
# Out:
# R2:  0.7562522590176881

# %%
cars = {'Time Period': ['6-month','2-year','3-year'],
        'MAE': [0.47,1.12,1.3]
        }
df = pd.DataFrame(cars)
df.plot(x='Period',y='MAE',)

# %%
[172.51, 173.05, 173.58, 174.12, 174.66, 175.19]

# %%
cars = {'Month': ['July','August','September','October','November','December'],
        'WPI': [164.72671682,
       164.66877249, 164.08066612, 165.02547874, 164.41988113,
       164.29862693],
        "WPI LAST YEAR": [165.8,165.4,165.0,163.7,163.1,162.2]
        }
df = pd.DataFrame(cars)
df.plot(x='Month',y=['WPI','WPI LAST YEAR'])

# %%
plt.figure(1, figsize=(16,10))
plt.plot(edgecolor='w', label='WPI')
plt.plot(X_train, ridge_regressor.predict(X_train), color='r', label='WPI LAST YEAR')
plt.xlabel('Month')
plt.ylabel('WPI')
plt.legend()
plt.show()
